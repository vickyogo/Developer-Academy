# %%
#import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# generating a line plot
y = np.linspace(-1,1,5)
x = np.arange(5)
fig = plt.figure()
ax = fig.subplots()
line1 = ax.plot(x,y)
y2 = np.linspace(-2,2,5)
line2 = ax.plot(x,y2)

# %%
number_rows = 3
number_columns = 2
fig2 = plt.figure()
ax2 = fig2.subplots(number_rows, number_columns)
ax2[0,1].plot(x,y)
ax2[0,1].plot(x,y2)
ax2[1,0].plot(x,y)
ax2[2,1].plot(x,y)

# %%
## showing plot
y3 = np.arange(0,110,10)
y4 = np.random.random(11)
x = np.arange(11)
fig, ax = plt.subplots(2,2)
ax[0,0].plot(x,y3)
ax[0,1].scatter(x,y4)
ax[1,0].bar(x,y3)
ax[1,1].barh(x,y3)
# Out:
# <BarContainer object of 11 artists>

# %%
x1 = np.arange(0, 4*np.pi, 0.05)
ycos = np.cos(x1)
ysin = np.sin(x1)
fig, ax = plt.subplots()
ax.plot(x1, ycos, 'b--', label = 'cos(x)')
ax.plot(x1, ysin, 'r-', label = 'sin(x)')

ax.set_title('Trigonometric function')
ax.set_xlabel('0 to 4pi')
ax.set_ylabel('cos(x) and sin(x)')
ax.legend()

# %%
#RGBA ------
fig, ax = plt.subplots(1,2)
ax[0].axhline(0.3, color = 'red')
ax[0].axhline(0.4, linestyle = '--', color = 'blue')
ax[0].axhline(0.5, color = 'cyan', linewidth = 10)
ax[0].axhline(0.6, linestyle = ':', xmin = 0.25, xmax = 0.75, color = 'orchid')
ax[0].axhline(0.7, xmin = 0.25, xmax = 0.75, color = (0.1, 0.2, 0.5, 0.3))

ax[1].axvline(0.3, color = 'red')
ax[1].axvline(0.4, linestyle = '--', color = 'blue')
ax[1].axvline(0.5, color = 'cyan', linewidth = 10)
ax[1].axvline(0.6, linestyle = ':', ymin = 0.25, ymax = 0.75, color = 'orchid')
ax[1].axvline(0.7, ymin = 0.25, ymax = 0.75, color = (0.1, 0.2, 0.5, 0.3))

# %%
##scatter plot
x = np.array(2,4,6,7,4,2,5,7,8,9,4,2,1)
y = np.array(7,5,4,1,6,7,8,1,9,5,9,3,5)
fig, ax = plt.subplots(1,3)
ax[0].scatter(x,y)
ax[0].set_title('default')
ax[1].scatter(x,y, 50, marker = '+')
ax[1].set_title('size = 50, style = +')
crosses = ax[2].scatter(x,y, 200, marker = '+', linewidth = 3)
bullets = ax[2].scatter(x,y, 50, marker = 'o', color = 'black')
bullets.set_edgecolor('red')
bullets.set_linewidth(1.5)
ax[2].set_title('mixed')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/vickyogo/Desktop/Developer Academy/visual.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> ##scatter plot
# ----> <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> x = np.array(2,4,6,7,4,2,5,7,8,9,4,2,1)
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> y = np.array(7,5,4,1,6,7,8,1,9,5,9,3,5)
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> fig, ax = plt.subplots(1,3)
#
# TypeError: array() takes from 1 to 2 positional arguments but 13 were given

# %%
z = np.array([0,1,4,3,5,1,2,5,7,5,9,8,5])
fig = plt.figure()
ax = np.array([fig.add_subplot(1,3,1, projection = '3d'),
               fig.add_subplot])
