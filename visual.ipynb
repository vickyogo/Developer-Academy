# %%
#import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# generating a line plot
y = np.linspace(-1,1,5)
x = np.arange(5)
fig = plt.figure()
ax = fig.subplots()
line1 = ax.plot(x,y)
y2 = np.linspace(-2,2,5)
line2 = ax.plot(x,y2)

# %%
number_rows = 3
number_columns = 2
fig2 = plt.figure()
ax2 = fig2.subplots(number_rows, number_columns)
ax2[0,1].plot(x,y)
ax2[0,1].plot(x,y2)
ax2[1,0].plot(x,y)
ax2[2,1].plot(x,y)

# %%
## showing plot
y3 = np.arange(0,110,10)
y4 = np.random.random(11)
x = np.arange(11)
fig, ax = plt.subplots(2,2)
ax[0,0].plot(x,y3)
ax[0,1].scatter(x,y4)
ax[1,0].bar(x,y3)
ax[1,1].barh(x,y3)
# Out:
# <BarContainer object of 11 artists>

# %%
x1 = np.arange(0, 4*np.pi, 0.05)
ycos = np.cos(x1)
ysin = np.sin(x1)
fig, ax = plt.subplots()
ax.plot(x1, ycos, 'b--', label = 'cos(x)')
ax.plot(x1, ysin, 'r-', label = 'sin(x)')

ax.set_title('Trigonometric function')
ax.set_xlabel('0 to 4pi')
ax.set_ylabel('cos(x) and sin(x)')
ax.legend()

# %%
#RGBA ------
fig, ax = plt.subplots(1,2)
ax[0].axhline(0.3, color = 'red')
ax[0].axhline(0.4, linestyle = '--', color = 'blue')
ax[0].axhline(0.5, color = 'cyan', linewidth = 10)
ax[0].axhline(0.6, linestyle = ':', xmin = 0.25, xmax = 0.75, color = 'orchid')
ax[0].axhline(0.7, xmin = 0.25, xmax = 0.75, color = (0.1, 0.2, 0.5, 0.3))

ax[1].axvline(0.3, color = 'red')
ax[1].axvline(0.4, linestyle = '--', color = 'blue')
ax[1].axvline(0.5, color = 'cyan', linewidth = 10)
ax[1].axvline(0.6, linestyle = ':', ymin = 0.25, ymax = 0.75, color = 'orchid')
ax[1].axvline(0.7, ymin = 0.25, ymax = 0.75, color = (0.1, 0.2, 0.5, 0.3))

# %%
##scatter plot
x = np.array([2,4,6,7,4,2,5,7,8,9,4,2,1])
y = np.array([7,5,4,1,6,7,8,1,9,5,9,3,5])
fig, ax = plt.subplots(1,3)
ax[0].scatter(x,y)
ax[0].set_title('default')
ax[1].scatter(x,y, 50, marker = '+')
ax[1].set_title('size = 50, style = +')
crosses = ax[2].scatter(x,y, 200, marker = '+', linewidth = 3)
bullets = ax[2].scatter(x,y, 50, marker = 'o', color = 'black')
bullets.set_edgecolor('red')
bullets.set_linewidth(1.5)
ax[2].set_title('mixed')
# Out:
# Text(0.5, 1.0, 'mixed')

# %%
z = np.array([0,1,4,3,5,1,2,5,7,5,9,8,5])
fig = plt.figure()
ax = np.array([fig.add_subplot(1,3,1, projection = '3d'),
               fig.add_subplot(1,3,2, projection='3d'),
               fig.add_subplot(1,3,3, projection='3d')])
ax[0].scatter(x,y,z)
ax[0].set_title('default')
ax[1].scatter(x,y,z, s=50, marker = '+')
ax[1].set_title('size = 50, marker = +')


crosses = ax[2].scatter(x,y,z, s =200, marker = '+', linewidth = 3)
bullets = ax[2].scatter(x,y,z, s = 50, marker = 'o', color = 'black')
bullets.set_edgecolors('red')
bullets.set_linewidth(1.5)
ax[2].set_title('mixed')
# Out:
# Text(0.5, 0.92, 'mixed')

# %%
## barplot
people = ['StudentA', 'StudentB']
StudentA = np.array([90,50,80,40])
StudentB = np.array([75,45,60,95])
X = np.arange(len(StudentA))
fig, ax = plt.subplots(1,2)
ax[0].bar(X, StudentA, width = 0.5)
ax[1].bar(X, StudentB, width = 0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
people = ['StudentA', 'StudentB']
StudentA = np.array([90,50,80,40])
StudentB = np.array([75,45,60,95])
X = np.arange(len(StudentA))
fig, ax = plt.subplots(1,2)
ax[0].bar(X, StudentA, width = 0.6)
ax[1].bar(X, StudentB, width = 0.6)
for i in range(len(ax)):
    ax[i].set_ylim([0,100])
    ax[i].set_title(people[i])
    ax[i].set_xlabel('exercises')
    ax[i].set_ylabel('mark (%)')
    ax[i].set_xticks([0,1,2,3])
    ax[i].set_xticklabels(['ex1', 'ex2', 'ex3', 'ex4'])

# %%
fig, ax = plt.subplots()
width = 0.3
s1bars = ax.bar(X-width/2, StudentA, width)
s2bars = ax.bar(X+width/2, StudentB, width)
ax.set_ylim([0, 100])
ax.set_title('Bar chart of student')
ax.set_xlabel("exercises")
ax.set_ylabel("mark (%)")
ax.set_xticks([0,1,2,3])
ax.set_xticklabels(["ex1","ex2","ex3","ex4"])
ax.legend((s1bars, s2bars), ('StudentA', 'StudentB'))

##iterate throught the bars 

for i in range(len(StudentA)):
    s1bars[i].set_linewidth(3.5)
    s2bars[i].set_linewidth(3.5)
    if StudentA[i] < 50:
        s1bars[i].set_edgecolor('red')
    if StudentB[i] < 50:
        s2bars[i].set_edgecolor('red')

# %%
fig, ax = plt.subplots()
ax.set_ylim([0, 20])
ax.set_xlim([-10, 10])
ax.axis('scaled')


# Rectangle
start_x = -2.5
start_y = 2
width = 5
height = 6
facecolor = 'gray'
## create a rectangle
rectangle = plt.Rectangle((start_x,start_y), width, height, 
                          fc=facecolor)
ax.add_patch(rectangle)

## add patch to it
rectangle = plt.Rectangle((-0.5,2), 1, 2, fc="brown")
ax.add_patch(rectangle)
## create a circle patch
circle1 = plt.Circle((-1,6), 0.5, fc='yellow', ec='black', lw=1)
ax.add_patch(circle1)

circle2 = plt.Circle((1,6), 0.5, fc="yellow", ec="black", lw=1)
ax.add_patch(circle2)

# Triangle
from matplotlib.patches import Polygon
## add triangle to it
start_xy = np.array([-2.5,8])
end_xy = np.array([2.5,8])
top_xy = np.array([0,10])

triangle = Polygon(np.vstack([start_xy, end_xy, top_xy]), color="red")
ax.add_patch(triangle)

##save the output
filename = 'house.jpeg'
plt.savefig(filename, format = 'jpeg')

# %%
# Get the Iris dataset
dataRaw = np.loadtxt('/Users/vickyogo/Downloads/iris-head-num.txt', delimiter=',', dtype='object')
# Get the header (first row)
header = dataRaw[0,:]
# Get the data (second row till end; 1-4th columns). Convert them to float
data = dataRaw[1:,:4]
data = np.vstack(data.astype(np.float32))
# Get the labels (second row; 4th columns)
labels = np.vstack(dataRaw[1:,4].astype(np.int32))
# Find unique labels and frequency
labelsUn, labelsCounts = np.unique(labels, return_counts=True)

# Find average, maximum, minimum and stand deviation of each column per category
nrows,ncols = np.shape(data) #number of rows and columns
nclasses = len(labelsUn)     #number of unique categories
#Initialise an nclasses-by-ncols per statistic
average = np.zeros((nclasses,ncols)) #mean
maxi = np.zeros((nclasses,ncols))    #maximum
mini = np.zeros((nclasses,ncols))    #minimum
sd = np.zeros((nclasses,ncols))      #standard deviation
for i in labelsUn:
    indexes = np.reshape(labels==i,nrows)
    average[i-1,:] = np.mean(data[indexes,:],axis=0)
    maxi[i-1,:] = np.max(data[indexes,:],axis=0)
    mini[i-1,:] = np.min(data[indexes,:],axis=0)
    sd[i-1,:] = np.std(data[indexes,:],axis=0)
    
    
#Errorbars with standard deviation
species = np.array(['setosa','versicolor','virginica'])
features = np.array(header[:-1].astype("U"))
x = np.arange(len(features))

fig, ax = plt.subplots()
for i in labelsUn:
    ax.errorbar(x, average[i-1,:], sd[i-1,:], marker="o", label=species[i-1]) 

#Aesthetics    
ax.legend(loc="upper right")    
ax.set_xlabel("features", fontsize=14, fontweight='bold')
ax.set_ylabel("mean +/- sd", fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(features, rotation=45)
fig.tight_layout()  #make sure that the axes labels fit the figure

# %%
#Boxplots (1)-----------------------------------------------------
data0 = [12, 10, 100, 11, 3, 20]
print("data : ", data)  
print("Q1 quantile of data : ", np.quantile(data0, .25)) 
print("Q2 quantile of data : ", np.quantile(data0, .50)) 
print("Q3 quantile of data : ", np.quantile(data0, .75)) 
print("median of data : ", np.median(data0)) 
print("mean of data : ", np.mean(data0)) 
fig, ax = plt.subplots()
ax.boxplot(data0)

#Boxplots (2)-----------------------------------------------------
outliers = dict(marker='+', markerfacecolor='black')
medians = dict(linewidth=2)
boxes = np.array([dict(facecolor='r',color='r'),
                  dict(facecolor='g',color='g'), 
                  dict(facecolor='b',color='b')])
    
mylegend = [plt.scatter([0],[0],facecolor='r', edgecolor='r', label=species[0]),
            plt.scatter([0],[0],facecolor='g', edgecolor='g', label=species[1]),
            plt.scatter([0],[0],facecolor='b', edgecolor='b', label=species[2])]
plt.close("all") #make sure that no figure is generated

x = -7
step = 5
fig, ax = plt.subplots()

for j in range(len(features)): #for each feature...
    x+= 7
    for i in labelsUn:         #for each category...
        indexes = np.reshape(labels==i,nrows)
        temp = data[indexes,j]
        ax.boxplot(temp, positions=[x],
                   widths=2,
                   patch_artist=True,
                   medianprops=medians,
                   boxprops=boxes[i-1],
                   flierprops=outliers)
        x+= step

ax.set_title("iris data set", fontsize=13, fontweight='bold')
ax.set_ylabel("values", fontweight='bold')
ax.set_xticks(np.arange(step,x,22))
ax.set_xticklabels(features, fontweight='bold', rotation=45)
ax.legend(handles=mylegend)
fig.tight_layout()  #make sure that the axes labels fit the figure
# Out:
# data :  [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# Q1 quantile of data :  10.25
# Q2 quantile of data :  11.5
# Q3 quantile of data :  18.0
# median of data :  11.5
# mean of data :  26.0

# %%
# data is a pandas series containing the counts of each type of network transmiting earthquake
data = work_data['net'].value_counts() 

# Create the pie chart
colors = ["#ff9999","#66b3ff","#99ff99","#ffcc99"]

#autopct parameter is used to format the values of the chart, 
# in this case it is showing the percentage with one decimal point.
explode = [ 1 if i < 0.1 else 0 for i in data/data.sum()]

# #labels parameter is used to provide the categories of the data, in this case the different types of networks
plt.pie(data, labels=data.index, autopct='%1.1f%%',colors=colors,explode = explode)

plt.title('Pie Chart of Networks', loc="center")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/vickyogo/Desktop/Developer Academy/visual.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # data is a pandas series containing the counts of each type of network transmiting earthquake
# ----> <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> data = work_data['net'].value_counts()
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> # Create the pie chart
#       <a href='vscode-notebook-cell:/Users/vickyogo/Desktop/Developer%20Academy/visual.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> colors = ["#ff9999","#66b3ff","#99ff99","#ffcc99"]
#
# NameError: name 'work_data' is not defined
